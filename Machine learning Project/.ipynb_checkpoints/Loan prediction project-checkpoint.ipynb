# %% [markdown]
# Import modules

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# Loading The Dataset

# %%
csvpath = "../csv/loan_data_set.csv"

# %%
dataset = pd.read_csv(csvpath)

# %%
dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
dataset.shape
# Out:
# (614, 13)

# %%
dataset.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#find the null values
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %% [markdown]
# Preprocessing The dataset

# %%
dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
# fill the missing values for numerical terms--mean
dataset['LoanAmount'] = dataset['LoanAmount'].fillna(dataset['LoanAmount'].mean())
dataset['Loan_Amount_Term'] = dataset['Loan_Amount_Term'].fillna(dataset['Loan_Amount_Term'].mean())
dataset['Credit_History'] = dataset['Credit_History'].fillna(dataset['Credit_History'].mean())

# %%
# filling the missing values for categorical terms -- mode
dataset['Gender'] = dataset['Gender'].fillna(dataset['Gender'].mode()[0])
dataset['Married'] = dataset['Married'].fillna(dataset['Married'].mode()[0])
dataset['Dependents'] = dataset['Dependents'].fillna(dataset['Dependents'].mode()[0])
dataset['Self_Employed'] = dataset['Self_Employed'].fillna(dataset['Self_Employed'].mode()[0])

# %%
dataset.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# Exploratory Data Analysis

# %%
sns.distplot(dataset['ApplicantIncome'])
# Out:
# C:\Users\sandh\AppData\Local\Temp\ipykernel_8976\2473572796.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['ApplicantIncome'])
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
sns.countplot(dataset['LoanAmount'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.distplot(dataset['Credit_History'])
# Out:
# C:\Users\sandh\AppData\Local\Temp\ipykernel_8976\3981447511.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['Credit_History'])
# <Axes: xlabel='Credit_History', ylabel='Density'>

# %%
for i in dataset[:-1]: 
    plt.figure(figsize=(15,10))
    plt.subplot(2,3,1)
    sns.countplot(x=i ,hue='Loan_Status', data = dataset ,palette='plasma')
    plt.xlabel(i, fontsize=14)

# %%
dataset['Gender'].value_counts()
# Out:
# Male      502
# Female    112
# Name: Gender, dtype: int64

# %%
sns.displot(dataset['ApplicantIncome'])

# %% [markdown]
# Correlation Matrix

# %%
sns.heatmap(dataset.corr() ,cmap='cubehelix_r')
# Out:
# C:\Users\sandh\AppData\Local\Temp\ipykernel_8976\2316813072.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dataset.corr() ,cmap='cubehelix_r')
# <Axes: >

# %%
#correlation table
corr = dataset.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# C:\Users\sandh\AppData\Local\Temp\ipykernel_8976\2118710382.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = dataset.corr()
# C:\Users\sandh\AppData\Local\Temp\ipykernel_8976\2118710382.py:3: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_1718b_row0_col0, #T_1718b_row1_col1, #T_1718b_row2_col2, #T_1718b_row3_col3, #T_1718b_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1718b_row0_col1, #T_1718b_row0_col4, #T_1718b_row1_col0, #T_1718b_row1_col3, #T_1718b_row4_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1718b_row0_col2 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_1718b_row0_col3, #T_1718b_row1_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_1718b_row1_col2 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_1718b_row2_col0 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_1718b_row2_col1 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_1718b_row2_col3, #T_1718b_row4_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_1718b_row2_col4 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_1718b_row3_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_1718b_row3_col1 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_1718b_row3_col2 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_1718b_row3_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_1718b_row4_col1 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_1718b_row4_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1718b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1718b_level0_col0" class="col_heading level0 col0" >ApplicantIncome</th>
#       <th id="T_1718b_level0_col1" class="col_heading level0 col1" >CoapplicantIncome</th>
#       <th id="T_1718b_level0_col2" class="col_heading level0 col2" >LoanAmount</th>
#       <th id="T_1718b_level0_col3" class="col_heading level0 col3" >Loan_Amount_Term</th>
#       <th id="T_1718b_level0_col4" class="col_heading level0 col4" >Credit_History</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1718b_level0_row0" class="row_heading level0 row0" >ApplicantIncome</th>
#       <td id="T_1718b_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_1718b_row0_col1" class="data row0 col1" >-0.12</td>
#       <td id="T_1718b_row0_col2" class="data row0 col2" >0.57</td>
#       <td id="T_1718b_row0_col3" class="data row0 col3" >-0.05</td>
#       <td id="T_1718b_row0_col4" class="data row0 col4" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_1718b_level0_row1" class="row_heading level0 row1" >CoapplicantIncome</th>
#       <td id="T_1718b_row1_col0" class="data row1 col0" >-0.12</td>
#       <td id="T_1718b_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_1718b_row1_col2" class="data row1 col2" >0.19</td>
#       <td id="T_1718b_row1_col3" class="data row1 col3" >-0.06</td>
#       <td id="T_1718b_row1_col4" class="data row1 col4" >-0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1718b_level0_row2" class="row_heading level0 row2" >LoanAmount</th>
#       <td id="T_1718b_row2_col0" class="data row2 col0" >0.57</td>
#       <td id="T_1718b_row2_col1" class="data row2 col1" >0.19</td>
#       <td id="T_1718b_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_1718b_row2_col3" class="data row2 col3" >0.04</td>
#       <td id="T_1718b_row2_col4" class="data row2 col4" >-0.01</td>
#     </tr>
#     <tr>
#       <th id="T_1718b_level0_row3" class="row_heading level0 row3" >Loan_Amount_Term</th>
#       <td id="T_1718b_row3_col0" class="data row3 col0" >-0.05</td>
#       <td id="T_1718b_row3_col1" class="data row3 col1" >-0.06</td>
#       <td id="T_1718b_row3_col2" class="data row3 col2" >0.04</td>
#       <td id="T_1718b_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_1718b_row3_col4" class="data row3 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_1718b_level0_row4" class="row_heading level0 row4" >Credit_History</th>
#       <td id="T_1718b_row4_col0" class="data row4 col0" >-0.01</td>
#       <td id="T_1718b_row4_col1" class="data row4 col1" >-0.00</td>
#       <td id="T_1718b_row4_col2" class="data row4 col2" >-0.01</td>
#       <td id="T_1718b_row4_col3" class="data row4 col3" >0.00</td>
#       <td id="T_1718b_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
dataset.shape
# Out:
# (614, 13)

# %%
#drop unnessary olumns
cols = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', "Loan_ID", "CoapplicantIncome"]
dataset = dataset.drop(columns= cols, axis = 1)
dataset.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# 3         Urban           Y
# 4         Urban           Y

# %% [markdown]
# Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
cols = ['Gender', 'Married', 'Education', 'Property_Area', 'Loan_Status', 'Dependents', 'Self_Employed', 'Credit_History']
le = LabelEncoder()
for col in cols:
    dataset[col] =le.fit_transform(dataset[col])

# %%
dataset
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0         1        0           0          0              0               2
# 1         1        1           1          0              0               2
# 2         1        1           0          0              1               2
# 3         1        1           0          1              0               2
# 4         1        0           0          0              0               2
# ..      ...      ...         ...        ...            ...             ...
# 609       0        0           0          0              0               2
# 610       1        1           3          0              0               2
# 611       1        1           1          0              0               2
# 612       1        1           2          0              0               2
# 613       0        0           0          0              1               0
#
#      Property_Area  Loan_Status
# 0                2            1
# 1                0            0
# 2                2            1
# 3                2            1
# 4                2            1
# ..             ...          ...
# 609              0            1
# 610              0            1
# 611              2            1
# 612              2            1
# 613              1            0
#
# [614 rows x 8 columns]

# %% [markdown]
# Split data into Independent & Dependent Variables

# %%
X = dataset.drop("Loan_Status", axis = 1) # Independent Variable

# %%
X
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0         1        0           0          0              0             1.0
# 1         1        1           1          0              0             1.0
# 2         1        1           0          0              1             1.0
# 3         1        1           0          1              0             1.0
# 4         1        0           0          0              0             1.0
# ..      ...      ...         ...        ...            ...             ...
# 609       0        0           0          0              0             1.0
# 610       1        1           3          0              0             1.0
# 611       1        1           1          0              0             1.0
# 612       1        1           2          0              0             1.0
# 613       0        0           0          0              1             0.0
#
#      Property_Area
# 0                2
# 1                0
# 2                2
# 3                2
# 4                2
# ..             ...
# 609              0
# 610              0
# 611              2
# 612              2
# 613              1
#
# [614 rows x 7 columns]

# %%
y = dataset["Loan_Status"] # dependent Variable

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, random_state = 42)

# %%
X_train
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 83        1        1           0          0              0        0.842199
# 90        1        1           0          0              0        1.000000
# 227       1        1           2          0              0        1.000000
# 482       1        1           0          0              0        1.000000
# 464       1        0           0          0              0        0.000000
# ..      ...      ...         ...        ...            ...             ...
# 71        1        1           2          1              1        1.000000
# 106       1        1           2          0              0        1.000000
# 270       0        0           0          0              0        1.000000
# 435       0        1           0          0              0        1.000000
# 102       1        1           0          0              0        1.000000
#
#      Property_Area
# 83               1
# 90               1
# 227              1
# 482              1
# 464              1
# ..             ...
# 71               1
# 106              2
# 270              2
# 435              1
# 102              2
#
# [491 rows x 7 columns]

# %%
X_train.shape
# Out:
# (491, 7)

# %%
X_test.shape
# Out:
# (123, 7)

# %% [markdown]
# Building the Decision Tree Model
#
#     Decision Tree
#     Random Forest
#     XGBoost
#     Logistic Regression

# %% [markdown]
# Building The Decision Tree

# %% [markdown]
# Model Training

# %%
# Classify function
from sklearn.model_selection import cross_val_score
def classify(model, X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.8, random_state = 42)
    model.fit(X_train, y_train)
    print("Accuracy is", model.score(X_test, y_test)*100)
    #cross valdation = it is used for better validation of model
    score = cross_val_score(model, X, y, cv = 5)
    print("Cross Validation is", np.mean(score)*100)

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
classify(model, X, y)
# Out:
# Accuracy is 78.86178861788618
# Cross Validation is 80.9462881514061

# %% [markdown]
# Building the Decision Tree Model

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt_model = DecisionTreeRegressor(criterion = "squared_error")

# %%
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# Prediction

# %%
y_pred = dt_model.predict(X_test)

# %%
y_pred
# Out:
# array([0.91428571, 0.5       , 1.        , 0.57142857, 0.78947368,
#        0.5       , 1.        , 1.        , 0.5       , 1.        ,
#        0.        , 0.69565217, 1.        , 0.66666667, 0.5       ,
#        0.83333333, 0.61904762, 0.78947368, 0.66666667, 0.91428571,
#        0.94117647, 1.        , 0.91428571, 0.66666667, 0.5       ,
#        0.71428571, 1.        , 0.78947368, 1.        , 1.        ,
#        0.8125    , 1.        , 1.        , 0.61904762, 0.57142857,
#        0.        , 0.94117647, 1.        , 1.        , 1.        ,
#        0.61904762, 0.8       , 1.        , 0.69565217, 0.61904762,
#        0.75      , 1.        , 0.        , 0.33333333, 0.2       ,
#        0.        , 0.90909091, 0.        , 1.        , 0.94117647,
#        0.66666667, 0.61904762, 1.        , 0.        , 1.        ,
#        0.        , 0.5       , 0.        , 1.        , 0.8125    ,
#        1.        , 1.        , 1.        , 1.        , 0.66666667,
#        0.        , 0.94117647, 1.        , 1.        , 0.        ,
#        1.        , 1.        , 0.        , 0.        , 0.78947368,
#        0.94117647, 0.8125    , 1.        , 1.        , 0.94117647,
#        1.        , 0.78571429, 0.        , 0.66666667, 0.69565217,
#        1.        , 0.25      , 0.        , 0.66666667, 0.91428571,
#        1.        , 1.        , 0.        , 1.        , 0.71428571,
#        0.91428571, 0.66666667, 0.55555556, 1.        , 1.        ,
#        0.        , 0.69565217, 0.        , 0.8       , 1.        ,
#        0.        , 0.        , 0.69565217, 0.5       , 0.83333333,
#        0.55555556, 0.94117647, 0.69565217, 0.69565217, 0.57142857,
#        0.66666667, 0.8125    , 0.94117647])

# %%
y_test
# Out:
# 350    1
# 377    1
# 163    1
# 609    1
# 132    1
#       ..
# 231    1
# 312    1
# 248    1
# 11     1
# 333    1
# Name: Loan_Status, Length: 123, dtype: int64

# %%
y_pred_train = dt_model.predict(X_train)

# %% [markdown]
# Evaluation

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
mse = mean_squared_error(y_test, y_pred)

# %%
rmse = np.sqrt(mse)

# %%
rmse
# Out:
# 0.46041341622698295

# %%
rmse_train = np.sqrt(mean_squared_error(y_train, y_pred_train))

# %%
rmse_train
# Out:
# 0.311272154322739

# %%
mae = mean_absolute_error(y_test, y_pred)

# %%
mae
# Out:
# 0.3076131515814171

# %%
print("Test data r2_score::", r2_score(y_test, y_pred))
# Out:
# Test data r2_score:: 0.06771709479284649

# %%
print("Train data r2_score::", r2_score(y_train, y_pred_train))
# Out:
# Train data r2_score:: 0.5416142029446231

# %%
from  sklearn.tree import plot_tree

# %%
plt.figure(figsize = (45, 15))
plot_tree(dt_model, filled = True, fontsize=10)
plt.show()

# %% [markdown]
# Random Forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
model = RandomForestClassifier()
classify(model, X, y)
model.fit(X_train, y_train)
# Out:
# Accuracy is 78.86178861788618
# Cross Validation is 76.55337864854059
# RandomForestClassifier()

# %%
model = ExtraTreesClassifier()
classify(model, X, y)
model.fit(X_train, y_train)
# Out:
# Accuracy is 73.98373983739837
# Cross Validation is 75.24856723977076
# ExtraTreesClassifier()

# %% [markdown]
# Hyperparameter Tunning

# %%
model = RandomForestClassifier(n_estimators = 100, min_samples_split = 25, max_depth = 7, max_features = 1)
classify(model, X, y)
# Out:
# Accuracy is 78.86178861788618
# Cross Validation is 80.9462881514061

# %% [markdown]
# Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[18, 25],
#        [ 1, 79]], dtype=int64)

# %%
sns.heatmap(cm, annot = True)
# Out:
# <Axes: >

# %%
import cv2

# %%
# Load an image with the float data type
image = cv2.imread("truck0.jpeg")

# %%
image
# Out:
# array([[[146, 131, 122],
#         [146, 131, 122],
#         [146, 131, 122],
#         ...,
#         [123, 100, 132],
#         [123, 100, 132],
#         [123, 100, 132]],
#
#        [[146, 131, 122],
#         [146, 131, 122],
#         [146, 131, 122],
#         ...,
#         [126, 103, 135],
#         [126, 103, 135],
#         [126, 103, 135]],
#
#        [[147, 132, 123],
#         [147, 132, 123],
#         [147, 132, 123],
#         ...,
#         [128, 107, 139],
#         [128, 107, 139],
#         [128, 107, 139]],
#
#        ...,
#
#        [[141, 157, 173],
#         [142, 158, 174],
#         [144, 160, 176],
#         ...,
#         [132, 142, 159],
#         [132, 142, 159],
#         [132, 142, 159]],
#
#        [[140, 156, 172],
#         [141, 157, 173],
#         [143, 159, 175],
#         ...,
#         [132, 142, 159],
#         [132, 142, 159],
#         [132, 142, 159]],
#
#        [[142, 158, 174],
#         [143, 159, 175],
#         [145, 161, 177],
#         ...,
#         [132, 142, 159],
#         [132, 142, 159],
#         [132, 142, 159]]], dtype=uint8)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(image)

# %% [markdown]
# Thresholding

# %% [markdown]
# Binary

# %%
doc_image = cv2.imread('passport.jpeg')

# %%
doc_image
# Out:
# array([[[177, 196, 234],
#         [177, 196, 234],
#         [177, 196, 234],
#         ...,
#         [203, 209, 220],
#         [203, 209, 220],
#         [203, 209, 220]],
#
#        [[175, 193, 230],
#         [175, 194, 229],
#         [175, 193, 230],
#         ...,
#         [190, 196, 207],
#         [191, 197, 208],
#         [191, 197, 208]],
#
#        [[166, 179, 211],
#         [166, 180, 209],
#         [166, 179, 211],
#         ...,
#         [188, 193, 202],
#         [188, 193, 202],
#         [188, 193, 202]],
#
#        ...,
#
#        [[122, 157, 230],
#         [122, 157, 230],
#         [122, 157, 230],
#         ...,
#         [158, 196, 254],
#         [158, 196, 254],
#         [158, 196, 254]],
#
#        [[122, 157, 230],
#         [122, 157, 230],
#         [122, 157, 230],
#         ...,
#         [158, 196, 254],
#         [158, 196, 254],
#         [158, 196, 254]],
#
#        [[122, 157, 230],
#         [122, 157, 230],
#         [122, 157, 230],
#         ...,
#         [158, 196, 254],
#         [158, 196, 254],
#         [158, 196, 254]]], dtype=uint8)

# %%
cv2.imshow("My Image", doc_image)
cv2.waitKey()
# Out:
# -1

# %%
gray_doc_img = cv2.cvtColor(doc_image, cv2.COLOR_BGR2GRAY)

# %%
gray_doc_img
# Out:
# array([[205, 205, 205, ..., 212, 212, 212],
#        [202, 202, 202, ..., 199, 200, 200],
#        [187, 187, 187, ..., 195, 195, 195],
#        ...,
#        [175, 175, 175, ..., 209, 209, 209],
#        [175, 175, 175, ..., 209, 209, 209],
#        [175, 175, 175, ..., 209, 209, 209]], dtype=uint8)

# %%
cv2.imshow("My Image", doc_image)
cv2.waitKey()
# Out:
# -1

# %% [markdown]
# Thresholding

# %% [markdown]
# Binary

# %%
gray_doc_img = cv2.cvtColor(doc_image, cv2.COLOR_BGR2GRAY)

# %%
gray_doc_img
# Out:
# array([[205, 205, 205, ..., 212, 212, 212],
#        [202, 202, 202, ..., 199, 200, 200],
#        [187, 187, 187, ..., 195, 195, 195],
#        ...,
#        [175, 175, 175, ..., 209, 209, 209],
#        [175, 175, 175, ..., 209, 209, 209],
#        [175, 175, 175, ..., 209, 209, 209]], dtype=uint8)

# %%
#image
#Threshold
#max VAlue
#Type of thresholding

thres_img = cv2.threshold(gray_doc_img, 110, 250, cv2.THRESH_BINARY)

# %%
thres_img
# Out:
# (110.0,
#  array([[250, 250, 250, ..., 250, 250, 250],
#         [250, 250, 250, ..., 250, 250, 250],
#         [250, 250, 250, ..., 250, 250, 250],
#         ...,
#         [250, 250, 250, ..., 250, 250, 250],
#         [250, 250, 250, ..., 250, 250, 250],
#         [250, 250, 250, ..., 250, 250, 250]], dtype=uint8))

# %%
gau_doc = cv2.GaussianBlur(doc_image, (3, 3), cv2.BORDER_DEFAULT)

# %%
gau_doc
# Out:
# array([[[176, 194, 231],
#         [176, 194, 231],
#         [176, 194, 231],
#         ...,
#         [195, 201, 212],
#         [195, 201, 212],
#         [195, 201, 212]],
#
#        [[173, 190, 224],
#         [173, 190, 225],
#         [173, 190, 224],
#         ...,
#         [194, 199, 210],
#         [194, 200, 210],
#         [194, 200, 210]],
#
#        [[165, 179, 209],
#         [165, 179, 210],
#         [165, 179, 209],
#         ...,
#         [190, 195, 205],
#         [190, 195, 205],
#         [190, 195, 205]],
#
#        ...,
#
#        [[122, 157, 230],
#         [122, 157, 230],
#         [122, 157, 230],
#         ...,
#         [158, 196, 254],
#         [158, 196, 254],
#         [158, 196, 254]],
#
#        [[122, 157, 230],
#         [122, 157, 230],
#         [122, 157, 230],
#         ...,
#         [158, 196, 254],
#         [158, 196, 254],
#         [158, 196, 254]],
#
#        [[122, 157, 230],
#         [122, 157, 230],
#         [122, 157, 230],
#         ...,
#         [158, 196, 254],
#         [158, 196, 254],
#         [158, 196, 254]]], dtype=uint8)

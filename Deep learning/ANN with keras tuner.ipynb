# %% [markdown]
# Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import keras_tuner as kt

# %%
csvpath = "../csv/Churn_Modelling.csv"

# %%
dataset = pd.read_csv(csvpath)

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
dataset["CustomerId"].nunique()#All customers are unique
# Out:
# 10000

# %%
dataset.shape
# Out:
# (10000, 14)

# %% [markdown]
# Missing Values¶

# %%
dataset.isnull().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
dataset
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
dataset.drop(["RowNumber","CustomerId","Surname"], axis = 1, inplace = True)

# %%
dataset
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
dataset["Geography"].unique()#Nominal
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
dataset["Gender"].unique()#Nominal
# Out:
# array(['Female', 'Male'], dtype=object)

# %% [markdown]
# One Hot Encoding

# %%
dataset = pd.get_dummies(dataset,columns=["Geography","Gender"],drop_first=True)

# %%
dataset
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1                  0
# ...

# %%
dataset.dtypes
# Out:
# CreditScore            int64
# Age                    int64
# Tenure                 int64
# Balance              float64
# NumOfProducts          int64
# HasCrCard              int64
# IsActiveMember         int64
# EstimatedSalary      float64
# Exited                 int64
# Geography_Germany      uint8
# Geography_Spain        uint8
# Gender_Male            uint8
# dtype: object

# %% [markdown]
# Split the Independent and Dependent variables¶

# %%
dataset.head(3)
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
# 2               0        113931.57       1                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# 2                0            0

# %%
#Independent variables
x = dataset.drop("Exited",axis = 1)

# %%
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 0                  1        101348.88                  0                0
# ...

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
x.shape
# Out:
# (10000, 11)

# %%
y = dataset["Exited"]

# %%
y.shape
# Out:
# (10000,)

# %% [markdown]
# Split the data into train and test set¶

# %%
from sklearn.model_selection import train_test_split

# %%
#20% --Test
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state = 42)

# %%
x_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9254          686   32       6       0.00              2          1
# 1561          632   42       4  119624.60              2          1
# 1670          559   24       3  114739.92              1          1
# 6087          561   27       9  135637.00              1          1
# 6669          517   56       9  142147.32              1          0
# ...           ...  ...     ...        ...            ...        ...
# 5734          768   54       8   69712.74              1          1
# 5191          682   58       1       0.00              1          1
# 5390          735   38       1       0.00              3          0
# 860           667   43       8  190227.46              1          1
# 7270          697   51       1  147910.30              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 9254               1        179093.26                  0                0
# ...

# %%
x_train.shape
# Out:
# (8000, 11)

# %%
x_test.shape
# Out:
# (2000, 11)

# %%
x_train
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9254          686   32       6       0.00              2          1
# 1561          632   42       4  119624.60              2          1
# 1670          559   24       3  114739.92              1          1
# 6087          561   27       9  135637.00              1          1
# 6669          517   56       9  142147.32              1          0
# ...           ...  ...     ...        ...            ...        ...
# 5734          768   54       8   69712.74              1          1
# 5191          682   58       1       0.00              1          1
# 5390          735   38       1       0.00              3          0
# 860           667   43       8  190227.46              1          1
# 7270          697   51       1  147910.30              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 9254               1        179093.26                  0                0
# ...

# %% [markdown]
# Scaling or Standardization or Normalization¶

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()#Creatin the object

# %%
#fit -- To apply the formula
#transform -- 
x_train = sc.fit_transform(x_train)

# %%
x_test = sc.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.35649971, -0.6557859 ,  0.34567966, ..., -0.57946723,
#         -0.57638802,  0.91324755],
#        [-0.20389777,  0.29493847, -0.3483691 , ...,  1.72572313,
#         -0.57638802,  0.91324755],
#        [-0.96147213, -1.41636539, -0.69539349, ..., -0.57946723,
#          1.73494238,  0.91324755],
#        ...,
#        [ 0.86500853, -0.08535128, -1.38944225, ..., -0.57946723,
#         -0.57638802, -1.09499335],
#        [ 0.15932282,  0.3900109 ,  1.03972843, ..., -0.57946723,
#         -0.57638802,  0.91324755],
#        [ 0.47065475,  1.15059039, -1.38944225, ...,  1.72572313,
#         -0.57638802,  0.91324755]])

# %%
#Sequential -- init the Neural Networ model
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Input

# %%
def nn_model(hp):
    model = Sequential()
    model.add(Input(shape = (x_train.shape[1],) ) )
              
    num_layers = hp.Int("num_layers", min_value = 1, max_value = 5)
    print("num_layes:", num_layers)
    for layers_number in range(num_layers):
        num_units = hp.Int(f"num_units_{layers_number}", min_value = 10, max_value = 30, step = 5)
        hidden_layer = Dense(num_units, kernel_initializer = "random_uniform", activation = "relu", bias_initializer = "random_uniform")
        model.add(hidden_layer)
              
        #output Layer
        output_layer = Dense(units = 1, kernel_initializer = "random_uniform", activation = "sigmoid", bias_initializer = "random_uniform")
        model.add(output_layer)
              
         #chosing different Learning rates 
        learning_rate = hp.choice("learning_rate", values = np.arange(0.001, 0.02, .002).tolist())
              
        adam_o = Adam(learning_rate = learning_rate_choice)
        sgd = SGD(learning_rate = learning_rate_chioce)
                
        optimizer_dict = {"sgd":sgd, "adam":adam_o}
            
            
            
         #choose optimizers
        hp_optimizer = hp.choice("optimizer", values = ["adam", "sgd"])
        optimizer_choice = optimizer_dict[hp_optimizer]
            
        recall_metric = Recall()  
              
        model.compile(loss = "binary_crossentropy", optimizer = optimizer_choice , metrics = [recall_metric])
        return model

# %%
from keras_tuner.tuners import RandomSearch

# %%
objective =  kt.Objective("val_recall", "max")

# %%
tuner_nn = RandomSearch(nn_model, objective = kt.Objective("val_recall", "max"), max_trials=10)
# Out:
# num_layes: 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 tuner_nn = RandomSearch(nn_model, objective = kt.Objective("val_recall", "max"), max_trials=10)
#
# File ~\anaconda3\lib\site-packages\keras_tuner\tuners\randomsearch.py:174, in RandomSearch.__init__(self, hypermodel, objective, max_trials, seed, hyperparameters, tune_new_entries, allow_new_entries, max_retries_per_trial, max_consecutive_failed_trials, **kwargs)
#     163 self.seed = seed
#     164 oracle = RandomSearchOracle(
#     165     objective=objective,
#     166     max_trials=max_trials,
#    (...)
#     172     max_consecutive_failed_trials=max_consecutive_failed_trials,
#     173 )
# --> 174 super().__init__(oracle, hypermodel, **kwargs)
#
# ...

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.1, random_state = 42)

# %%
tuner_nn.search(x_train, y_train, epochs = 35, batch_size = 32, validation_data = (x_val, y_val))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 tuner_nn.search(x_train, y_train, epochs = 35, batch_size = 32, validation_data = (x_val, y_val))
#
# NameError: name 'tuner_nn' is not defined

# %% [markdown]
# # Project - 1 Mobiles Brands and Prices

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import re
import time
import requests
from bs4 import BeautifulSoup
import csv

# %%
# Identify the URL
URL = 'https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
URL
# Out:
# 'https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %%
#loading web page
htmlpage =requests.get(URL)

# %%
type(htmlpage)
# Out:
# requests.models.Response

# %%
htmlpage.status_code
# Out:
# 200

# %%
htmlpage.text
# Out:
# '<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.4fb0ab.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https:///www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57
# ...

# %%
soup = BeautifulSoup(htmlpage.text)

# %%
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.905c37.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.4fb0ab.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https:///www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
#   <meta content="Flipkart.com" name="og_site_name" property="og:site_name"/>
# ...

# %%
price: _30jeq3 _1_WHN1
rating: _3LWZlK
    
features: fMghEO
title: _4rR01T
# Out:
#   File "C:\Users\Yuvaraj\AppData\Local\Temp\ipykernel_18056\824927029.py", line 1
#     price: _30jeq3 _1_WHN1
#                    ^
# SyntaxError: invalid syntax

# %%
price = soup.find('div', attrs = {'class': '_30jeq3 _1_WHN1'})
price
# Out:
# <div class="_30jeq3 _1_WHN1">₹49,999</div>

# %%
price.text
# Out:
# '₹49,999'

# %%
title = soup.find('div', attrs = {'class': '_4rR01T'})
title.text
# Out:
# 'MOTOROLA Edge 30 Ultra (Interstellar Black, 128 GB)'

# %%
features = soup.find('div', attrs = {'fMghEO'})
features.text
# Out:
# '8 GB RAM | 128 GB ROM16.94 cm (6.67 inch) Full HD+ Display200MP + 50MP + 12MP | 60MP Front Camera4610 mAh Lithium BatteryQualcomm Snapdragon 8+ Gen 1 Processor1 Year on Handset and 6 Months on Accessories'

# %%
rating = soup.find('div', attrs = {'class': '_3LWZlK'})
rating.text
# Out:
# '4.3'

# %%
title = soup.find('div', attrs = {'class': '_4rR01T'})
title
# Out:
# <div class="_4rR01T">MOTOROLA Edge 30 Ultra (Interstellar Black, 128 GB)</div>

# %% [markdown]
# # find_all()

# %%
title = soup.find_all('div', attrs = {'class': '_4rR01T'})
title
# Out:
# [<div class="_4rR01T">MOTOROLA Edge 30 Ultra (Interstellar Black, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy A73 5G (Awesome Gray, 256 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy S21 FE 5G (Graphite, 128 GB)</div>,
#  <div class="_4rR01T">Xiaomi 12 Pro 5G (Noir Black, 256 GB)</div>,
#  <div class="_4rR01T">Xiaomi 12 Pro 5G (Opera Mauve, 256 GB)</div>,
#  <div class="_4rR01T">MOTOROLA Edge 30 Ultra (Starlight White, 128 GB)</div>,
#  <div class="_4rR01T">SAMSUNG Galaxy S22 5G (Bora Purple, 128 GB)</div>,
#  <div class="_4rR01T">APPLE iPhone 11 (Red, 128 GB)</div>,
#  <div class="_4rR01T">Xiaomi 12 Pro 5G (Noir Black, 256 GB)</div>,
#  <div class="_4rR01T">OnePlus 10 Pro 5G (Volcanic Black, 128 GB)</div>,
#  <div class="_4rR01T">realme X50 Pro 5G (Rust Red, 256 GB)</div>,
#  <div class="_4rR01T">IQOO 9T 5G (LEGEND, 128 GB)</div>,
#  <div class="_4rR01T">OnePlus 10T 5G (Moonstone Black, 128 GB)</div>,
#  <div class="_4rR01T">realme GT 2 Pro (Paper Green, 128 GB)</div>,
# ...

# %%
len(title)
# Out:
# 24

# %%
for i in title:
    print(i.text)
# Out:
# MOTOROLA Edge 30 Ultra (Interstellar Black, 128 GB)
# SAMSUNG Galaxy A73 5G (Awesome Gray, 256 GB)
# SAMSUNG Galaxy S21 FE 5G (Graphite, 128 GB)
# Xiaomi 12 Pro 5G (Noir Black, 256 GB)
# Xiaomi 12 Pro 5G (Opera Mauve, 256 GB)
# MOTOROLA Edge 30 Ultra (Starlight White, 128 GB)
# SAMSUNG Galaxy S22 5G (Bora Purple, 128 GB)
# APPLE iPhone 11 (Red, 128 GB)
# Xiaomi 12 Pro 5G (Noir Black, 256 GB)
# OnePlus 10 Pro 5G (Volcanic Black, 128 GB)
# realme X50 Pro 5G (Rust Red, 256 GB)
# IQOO 9T 5G (LEGEND, 128 GB)
# OnePlus 10T 5G (Moonstone Black, 128 GB)
# realme GT 2 Pro (Paper Green, 128 GB)
# realme GT 2 Pro (Paper White, 128 GB)
# Mi 10T Pro (Cosmic Black, 128 GB)
# realme GT 2 Pro (Steel Black, 128 GB)
# realme X50 Pro (Moss Green, 256 GB)
# SAMSUNG Galaxy S7 (Gold Platinum, 32 GB)
# OnePlus 10 Pro 5G (Emerald Forest, 128 GB)
# OnePlus 10T 5G (Jade Green, 128 GB)
# OPPO Reno8 Pro 5G (Glazed Black, 256 GB)
# Xiaomi 12 Pro 5G (Opera Mauve, 256 GB)
# Xiaomi 12 Pro 5G (Couture Blue, 256 GB)

# %%
rating = soup.find_all('div', attrs = {'class': '_3LWZlK'})
rating
# Out:
# [<div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div>,
# ...

# %%
len(rating)
# Out:
# 39

# %%
search mobiles: _3pLy-c row
# Out:
#   File "C:\Users\Yuvaraj\AppData\Local\Temp\ipykernel_18056\1257423834.py", line 1
#     search mobiles: _3pLy-c row
#            ^
# SyntaxError: invalid syntax

# %%
search_mobiles = soup.find_all('div', attrs = {'class': '_3pLy-c row'})
search_mobiles
# Out:
# [<div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">MOTOROLA Edge 30 Ultra (Interstellar Black, 128 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBGFGM2PHKKGB78NUNL0L_MOBGFGM2PHKKGB78_"><div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>1,188 Ratings </span><span class="_13vcmD">&amp;</span><span> 225 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">8 GB RAM | 128 GB ROM</li><li class="rgWa7D">16.94 cm (6.67 inch) Full HD+ Display</li><li class="rgWa7D">200MP + 50MP + 12MP | 60MP Front Camera</li><li class="rgWa7D">4610 mAh Lithium Battery</li><li class="rgWa7D">Qualcomm Snapdragon 8+ Gen 1 Processor</li><li class="rgWa7D">1 Year on Handset and 6 Months on Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹49,999</div><div class="_3I9_wc _27UcVY">₹<!-- -->
# ...

# %%
len(search_mobiles)
# Out:
# 24

# %%
search_mobiles[0]
# Out:
# <div class="_3pLy-c row"><div class="col col-7-12"><div class="_4rR01T">MOTOROLA Edge 30 Ultra (Interstellar Black, 128 GB)</div><div class="gUuXy-"><span class="_1lRcqv" id="productRating_LSTMOBGFGM2PHKKGB78NUNL0L_MOBGFGM2PHKKGB78_"><div class="_3LWZlK">4.3<img class="_1wB99o" src="..."/></div></span><span class="_2_R_DZ"><span><span>1,188 Ratings </span><span class="_13vcmD">&amp;</span><span> 225 Reviews</span></span></span></div><div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">8 GB RAM | 128 GB ROM</li><li class="rgWa7D">16.94 cm (6.67 inch) Full HD+ Display</li><li class="rgWa7D">200MP + 50MP + 12MP | 60MP Front Camera</li><li class="rgWa7D">4610 mAh Lithium Battery</li><li class="rgWa7D">Qualcomm Snapdragon 8+ Gen 1 Processor</li><li class="rgWa7D">1 Year on Handset and 6 Months on Accessories</li></ul></div></div><div class="col col-5-12 nlI3QM"><div class="_3tbKJL"><div class="_25b18c"><div class="_30jeq3 _1_WHN1">₹49,999</div><div class="_3I9_wc _27UcVY">₹<!-- -->6
# ...

# %%
search_mobiles[0].find('div', attrs = {'class': '_30jeq3 _1_WHN1'})
# Out:
# <div class="_30jeq3 _1_WHN1">₹49,999</div>

# %%
len(search_mobiles)
# Out:
# 24

# %%
for mobiles in search_mobiles:
    m = mobiles.find('div', attrs = {'class': '_30jeq3 _1_WHN1'})
    print(m.text)
# Out:
# ₹49,999
# ₹42,999
# ₹54,999
# ₹49,990
# ₹45,990
# ₹49,999
# ₹51,899
# ₹46,999
# ₹45,990
# ₹49,470
# ₹47,999
# ₹49,499
# ₹43,990
# ₹49,999
# ₹49,999
# ₹47,999
# ₹49,999
# ₹47,999
# ₹46,000
# ₹49,700
# ₹47,995
# ₹45,999
# ₹50,980
# ₹47,999

# %%
rating = []
for mobiles in search_mobiles:
    r = mobiles.find('div', attrs = {'class': '_3LWZlK'})
    rating.append(r.text)
len(rating)
# Out:
# 24

# %%
rating
# Out:
# ['4.3',
#  '4.2',
#  '4.3',
#  '4.2',
#  '4.1',
#  '4.3',
#  '4.3',
#  '4.6',
#  '4.1',
#  '4.2',
#  '4.4',
#  '4.1',
#  '4.3',
#  '4.3',
#  '4.3',
#  '4.2',
#  '4.3',
#  '4.4',
#  '4.4',
#  '4.2',
#  '4.3',
#  '4.4',
#  '4.2',
#  '4.1']

# %%
price: _30jeq3 _1_WHN1
rating: _3LWZlK
    
features: fMghEO
title: _4rR01T
# Out:
#   File "C:\Users\Yuvaraj\AppData\Local\Temp\ipykernel_18056\824927029.py", line 1
#     price: _30jeq3 _1_WHN1
#                    ^
# SyntaxError: invalid syntax

# %%
title = []
for mobiles in search_mobiles:
    t = mobiles.find('div', attrs = {'class': '_4rR01T'})
    title.append(r.text)
len(title)
# Out:
# 24

# %%
price = []
for mobiles in search_mobiles:
        p = mobiles.find('div', attrs = {'class': '_30jeq3 _1_WHN1'})
        price.append(p.text)

# %%
price
# Out:
# ['₹49,999',
#  '₹42,999',
#  '₹54,999',
#  '₹49,990',
#  '₹45,990',
#  '₹49,999',
#  '₹51,899',
#  '₹46,999',
#  '₹45,990',
#  '₹49,470',
#  '₹47,999',
#  '₹49,499',
#  '₹43,990',
#  '₹49,999',
#  '₹49,999',
#  '₹47,999',
#  '₹49,999',
#  '₹47,999',
#  '₹46,000',
#  '₹49,700',
#  '₹47,995',
#  '₹45,999',
#  '₹50,980',
#  '₹47,999']

# %%
features
# Out:
# <div class="fMghEO"><ul class="_1xgFaf"><li class="rgWa7D">8 GB RAM | 128 GB ROM</li><li class="rgWa7D">16.94 cm (6.67 inch) Full HD+ Display</li><li class="rgWa7D">200MP + 50MP + 12MP | 60MP Front Camera</li><li class="rgWa7D">4610 mAh Lithium Battery</li><li class="rgWa7D">Qualcomm Snapdragon 8+ Gen 1 Processor</li><li class="rgWa7D">1 Year on Handset and 6 Months on Accessories</li></ul></div>

# %%
features = []
for mobiles in search_mobiles:
    f = mobiles.find('div', attrs = {'class': 'fMghEO'})
    if (f is None):
        features.append(np.nan)
    else:
        features.append(f.text)

len(features)
# Out:
# 24

# %%
features
# Out:
# ['8 GB RAM | 128 GB ROM16.94 cm (6.67 inch) Full HD+ Display200MP + 50MP + 12MP | 60MP Front Camera4610 mAh Lithium BatteryQualcomm Snapdragon 8+ Gen 1 Processor1 Year on Handset and 6 Months on Accessories',
#  '8 GB RAM | 256 GB ROM | Expandable Upto 1 TB17.02 cm (6.7 inch) Full HD+ Display108MP + 12MP + 5MP + 5MP | 32MP Front Camera5000 mAh Li-ion BatteryQualcomm Snapdragon 778G Processor1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box',
#  '8 GB RAM | 128 GB ROM16.26 cm (6.4 inch) Full HD+ Display12MP + 12MP + 8MP (OIS) | 32MP Front Camera4500 mAh Lithium-ion Battery1 Year Manufacturer Warranty for Device and 6 Months Manufacturer Warranty for In-Box Accessories',
#  '12 GB RAM | 256 GB ROM17.09 cm (6.73 inch) Full HD+ AMOLED Display50MP Rear Camera4600 mAh BatterySnapdragon@ 8 Gen 1 Processor12 Months',
# ...

# %%
for page in range(1,10):
    URL = 'https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
    print(URL)
# Out:
# https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off
# https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off
# https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off
# https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off
# https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off
# https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off
# https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off
# ...

# %%
for page in range(1,62):
    
    url = f'https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
     #print(url)
   
    
    htmlpage = requests.get(URL)
    soup = BeautifulSoup(htmlpage.text)
    
    search_laptops = soup.find_all('div', attrs = {'class': '_3pLy-c row'})
    
    prices = []
    ratings = []
    features = []
    titles = []
    for laptop in search_laptops:
        
        p = mobiles.find('div', attrs = {'class': '_30jeq3 _1_WHN1'})
        if(p is None):
            prices.append(np.nan)
        else:
            prices.append(p.text)
            
            
        p = mobiles.find('div', attrs = {'class': '_3LWZlK'})
        if(p is None):
            ratings.append(np.nan)
        else:
            ratings.append(p.text)
            
            
        p = mobiles.find('div', attrs = {'class': 'fMghEO'})
        if(p is None):
            features.append(np.nan)
        else:
            features.append(p.text)
            
            
        p = mobiles.find('div', attrs = {'class': '_4rR01T'})
        if(p is None):
            titles.append(np.nan)
        else:
            titles.append(p.text)

# %%
len(prices), len(ratings), len(features)
# Out:
# (24, 24, 24)

# %%
    prices = []
    ratings = []
    features = []
    titles = []
    for page in range(1,3):
    
    url = f'https://www.flipkart.com/search?q=mobiles%20under%2050000&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'
     #print(url)
   
    
    htmlpage = requests.get(URL)
    soup = BeautifulSoup(htmlpage.text)
    
    search_laptops = soup.find_all('div', attrs = {'class': '_3pLy-c row'})
    
  
    for laptop in search_laptops:
        
        p = mobiles.find('div', attrs = {'class': '_30jeq3 _1_WHN1'})
        if(p is None):
            prices.append(np.nan)
        else:
            prices.append(p.text)
            
            
        p = mobiles.find('div', attrs = {'class': '_3LWZlK'})
        if(p is None):
            ratings.append(np.nan)
        else:
            ratings.append(p.text)
            
            
        p = mobiles.find('div', attrs = {'class': 'fMghEO'})
        if(p is None):
            features.append(np.nan)
        else:
            features.append(p.text)
            
            
        p = mobiles.find('div', attrs = {'class': '_4rR01T'})
        if(p is None):
            titles.append(np.nan)
        else:
            titles.append(p.text)

# %%
mobiles_df = pd.DataFrame=({ 'Title': title,
                            'price': price,
                           'ratings': rating,
                           'Featues':features })
mobiles_df
